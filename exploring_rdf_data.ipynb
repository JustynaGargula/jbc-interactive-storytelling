# %% [markdown]
# # Opis
# Ten notes zawiera funkcje do łączenia i eksplorowania danych. Najpierw dane łączone są w jeden graf wiedzy, a następnie wykonywane są na nich różne zapytania.
# ## Opisy poszczególnych funkcji
#
# - create_graph(directory_path_with_rdfs)
#
#     Tworzy graf z danymi z plików `.rdf`.
#
#     Wymagane parametry:
#     - **directory_path_with_rdfs** - ścieżka do folderu z plikami w formacie `.rdf`
#
# - visualise_graph(graph):
#
#     Tworzy plik html z wizualizacją grafu.
#
#     Wymagane parametry:
#     - **graph** - graph stworzony przez `create_graph()`

# %%
from rdflib import Graph, Namespace
import glob

# %%
def create_graph(directory_path_with_rdfs, generate_files):
    graph = Graph()

    for rdf_file in glob.glob(directory_path_with_rdfs):
        graph.parse(rdf_file)
    print(f"Łącznie wczytano {len(graph)} trójek.")

    if generate_files:
        graph.serialize("./data/merged_graph.rdf", format="xml")
        graph.serialize("./data/merged_graph_turtle.ttl", format="turtle")

    return graph

# %%
rdfs_directory_path = "./data/part1/*rdf"
g = create_graph(rdfs_directory_path, False)
# Out:
# Łącznie wczytano 3388 trójek.

# %%
# właściwości używane w grafie

q = """
SELECT DISTINCT ?p WHERE {
    # ?s ?p ?o .
}
ORDER BY ?p
"""
for row in g.query(q):
    print(row[0])
# Out:
# http://purl.org/dc/elements/1.1/coverage
# http://purl.org/dc/elements/1.1/creator
# http://purl.org/dc/elements/1.1/date
# http://purl.org/dc/elements/1.1/description
# http://purl.org/dc/elements/1.1/format
# http://purl.org/dc/elements/1.1/identifier
# http://purl.org/dc/elements/1.1/issued
# http://purl.org/dc/elements/1.1/language
# http://purl.org/dc/elements/1.1/publisher
# http://purl.org/dc/elements/1.1/relation
# http://purl.org/dc/elements/1.1/rights
# http://purl.org/dc/elements/1.1/source
# http://purl.org/dc/elements/1.1/subject
# http://purl.org/dc/elements/1.1/title
# http://purl.org/dc/elements/1.1/type

# %%
# sprawdzenie wartości dla kilku właściwości

fields = ["dc:coverage", "dc:type", "dc:creator", "dc:format", "dc:publisher", "dc:relation", "dc:subject"]

dc = Namespace("http://purl.org/dc/elements/1.1/")

for field in fields:
    q = f"""
    SELECT DISTINCT ?value WHERE {{
        # ?s {field} ?value .
    }}
    LIMIT 20
    """
    print(10*"*"+field+10*"*")
    for row in g.query(q, initNs={"dc": dc}):
        print(row[0])
    print()
# Out:
# **********dc:coverage**********
# 20 w.
# 19 w.
# 19-20 w.
# 20-21 w.
#
# **********dc:type**********
# rozprawa doktorska
# druk ulotny
# afisz
# plakat
# klepsydra
#
# **********dc:creator**********
# Gęsiak, Leszek
# Labour Party
# Cambridge Anglo-Polish Society
#
# **********dc:format**********
# image/x.djvu
# image/x.djvu
# application/octet-stream
# application/octet-stream
# pdf
#
# **********dc:publisher**********
# Uniwersytet Jagielloński w Krakowie
# I. Związkowa Drukarnia
# Jermułowicz i Bergman
# M. Stochalski
#
# **********dc:relation**********
# oai:jbc.bj.uj.edu.pl:publication:180039
# oai:jbc.bj.uj.edu.pl:publication:180039
# oai:jbc.bj.uj.edu.pl:publication:421001
# oai:jbc.bj.uj.edu.pl:publication:421001
# oai:jbc.bj.uj.edu.pl:publication:535690
# oai:jbc.bj.uj.edu.pl:publication:535691
# oai:jbc.bj.uj.edu.pl:publication:579328
# oai:jbc.bj.uj.edu.pl:publication:579397
# oai:jbc.bj.uj.edu.pl:publication:579399
# oai:jbc.bj.uj.edu.pl:publication:579419
# oai:jbc.bj.uj.edu.pl:publication:599804
# oai:jbc.bj.uj.edu.pl:publication:599842
# oai:jbc.bj.uj.edu.pl:publication:599998
# oai:jbc.bj.uj.edu.pl:publication:600001
# oai:jbc.bj.uj.edu.pl:publication:600002
# oai:jbc.bj.uj.edu.pl:publication:600330
# oai:jbc.bj.uj.edu.pl:publication:600353
# oai:jbc.bj.uj.edu.pl:publication:601649
# oai:jbc.bj.uj.edu.pl:publication:601724
# https://audiovis.nac.gov.pl/search/bce12eb58b7c438c284cce758f457f0c:1/ Zobacz w NAC, Fragment przedstawienia Ludwika Hieronima Morstina „Mikołaj Kopernik” (1936-1937)
#
# **********dc:subject**********
# religion
# society
# wartości rdzenne
# state
# państwo
# core values
# wielokulturowość
# multiculturalism
# społeczeństwo
# religia
# laburzyści
# Partia Pracy (Wielka Brytania)
# druki ulotne 20 w.
# Ciołkosz, Adam (1901-1978)
# druki ulotne 19 w.
# Wydawnictwo „Czytelni Ludowej”
# Teatr Krakowski 19 w.
# Sienkiewicz, Henryk (1846-1916)
# Chaumont, Céline (1848-1926)
# Towarzystwo Paryskie

# %%
# 5 przykładowych dokumentów

sample = """
SELECT DISTINCT ?s WHERE {
    # ?s dc:title ?t .
}
LIMIT 5
"""

docs = [row[0] for row in g.query(sample, initNs={"dc": dc})]

for doc in docs:
    print("--- DOCUMENT ---")
    q = f"""
    SELECT ?p ?o WHERE {{
        <{doc}> ?p ?o .
    }}
    """
    for row in g.query(q):
        print(row[0], "→", row[1])
    print()
# Out:
# --- DOCUMENT ---
# http://purl.org/dc/elements/1.1/publisher → Uniwersytet Jagielloński w Krakowie
# http://purl.org/dc/elements/1.1/subject → religion
# http://purl.org/dc/elements/1.1/subject → society
# http://purl.org/dc/elements/1.1/subject → wartości rdzenne
# http://purl.org/dc/elements/1.1/subject → state
# http://purl.org/dc/elements/1.1/subject → państwo
# http://purl.org/dc/elements/1.1/subject → core values
# http://purl.org/dc/elements/1.1/subject → wielokulturowość
# http://purl.org/dc/elements/1.1/subject → multiculturalism
# http://purl.org/dc/elements/1.1/subject → społeczeństwo
# http://purl.org/dc/elements/1.1/subject → religia
# http://purl.org/dc/elements/1.1/relation → oai:jbc.bj.uj.edu.pl:publication:180039
# http://purl.org/dc/elements/1.1/relation → oai:jbc.bj.uj.edu.pl:publication:180039
# http://purl.org/dc/elements/1.1/format → image/x.djvu
# http://purl.org/dc/elements/1.1/format → image/x.djvu
# http://purl.org/dc/elements/1.1/creator → Gęsiak, Leszek
# http://purl.org/dc/elements/1.1/source → Archiwum UJ, Dokt. 2004/193
# http://purl.org/dc/elements/1.1/rights → Copyright
# http://purl.org/dc/elements/1.1/issued → 2004
# http://purl.org/dc/elements/1.1/type → rozprawa doktorska
# http://purl.org/dc/elements/1.1/title → Wielokulturowość - rola religii w dynamice zjawiska
# http://purl.org/dc/elements/1.1/date → 2004
# http://purl.org/dc/elements/1.1/language → pol
#
# --- DOCUMENT ---
# http://purl.org/dc/elements/1.1/title → „Your Future”
# http://purl.org/dc/elements/1.1/source → Biblioteka Jagiellońska, 639986 III 110
# http://purl.org/dc/elements/1.1/date → ca 1946
# http://purl.org/dc/elements/1.1/issued → ca 1946
# http://purl.org/dc/elements/1.1/relation → oai:jbc.bj.uj.edu.pl:publication:421001
# http://purl.org/dc/elements/1.1/relation → oai:jbc.bj.uj.edu.pl:publication:421001
# http://purl.org/dc/elements/1.1/language → eng
# http://purl.org/dc/elements/1.1/creator → Labour Party
# http://purl.org/dc/elements/1.1/subject → laburzyści
# http://purl.org/dc/elements/1.1/subject → Partia Pracy (Wielka Brytania)
# http://purl.org/dc/elements/1.1/subject → druki ulotne 20 w.
# http://purl.org/dc/elements/1.1/coverage → 20 w.
# http://purl.org/dc/elements/1.1/type → druk ulotny
# http://purl.org/dc/elements/1.1/rights → Domena publiczna (public domain)
# http://purl.org/dc/elements/1.1/format → application/octet-stream
# http://purl.org/dc/elements/1.1/format → application/octet-stream
# http://purl.org/dc/elements/1.1/identifier → https://jbc.bj.uj.edu.pl/Content/499435/NDIGDZS024864.pdf
# http://purl.org/dc/elements/1.1/identifier → https://jbc.bj.uj.edu.pl/Content/499435/NDIGDZS024864.pdf
#
# --- DOCUMENT ---
# http://purl.org/dc/elements/1.1/subject → druki ulotne 20 w.
# http://purl.org/dc/elements/1.1/subject → Ciołkosz, Adam (1901-1978)
# http://purl.org/dc/elements/1.1/rights → Domena publiczna (public domain)
# http://purl.org/dc/elements/1.1/identifier → https://jbc.bj.uj.edu.pl/Content/510136/NDIGDZS023940.pdf
# http://purl.org/dc/elements/1.1/source → Biblioteka Jagiellońska, 639986 III 78
# http://purl.org/dc/elements/1.1/type → druk ulotny
# http://purl.org/dc/elements/1.1/issued → 1948
# http://purl.org/dc/elements/1.1/creator → Cambridge Anglo-Polish Society
# http://purl.org/dc/elements/1.1/title → Dr. Adam Ciolkosz [...] will speak on „Central & South-Eastern European Federation, is it possible, is it advisable?”
# http://purl.org/dc/elements/1.1/relation → oai:jbc.bj.uj.edu.pl:publication:535690
# http://purl.org/dc/elements/1.1/language → eng
# http://purl.org/dc/elements/1.1/date → 1948
# http://purl.org/dc/elements/1.1/coverage → 20 w.
#
# --- DOCUMENT ---
# http://purl.org/dc/elements/1.1/coverage → 20 w.
# http://purl.org/dc/elements/1.1/relation → oai:jbc.bj.uj.edu.pl:publication:535691
# http://purl.org/dc/elements/1.1/rights → Domena publiczna (public domain)
# http://purl.org/dc/elements/1.1/identifier → https://jbc.bj.uj.edu.pl/Content/510137/NDIGDZS023948.pdf
# http://purl.org/dc/elements/1.1/source → Biblioteka Jagiellońska, 639986 III 85
# http://purl.org/dc/elements/1.1/subject → druki ulotne 20 w.
# http://purl.org/dc/elements/1.1/title → British Fund for Warsaw : (under the auspices of the Poland Relief Fund)
# http://purl.org/dc/elements/1.1/issued → ca 1948
# http://purl.org/dc/elements/1.1/type → druk ulotny
# http://purl.org/dc/elements/1.1/date → ca 1948
# http://purl.org/dc/elements/1.1/language → eng
#
# --- DOCUMENT ---
# http://purl.org/dc/elements/1.1/issued → ca 1900
# http://purl.org/dc/elements/1.1/language → pol
# http://purl.org/dc/elements/1.1/relation → oai:jbc.bj.uj.edu.pl:publication:579328
# http://purl.org/dc/elements/1.1/subject → druki ulotne 19 w.
# http://purl.org/dc/elements/1.1/title → Kundmachung : Aussergewöhnliche Markt Anzeige
# http://purl.org/dc/elements/1.1/rights → Domena publiczna (public domain)
# http://purl.org/dc/elements/1.1/coverage → 19 w.
# http://purl.org/dc/elements/1.1/identifier → https://jbc.bj.uj.edu.pl/Content/550767/NDIGDZS019096.pdf
# http://purl.org/dc/elements/1.1/date → ca 1900
# http://purl.org/dc/elements/1.1/type → afisz
# http://purl.org/dc/elements/1.1/source → Biblioteka Jagiellońska, 224655 V 20

# %% [markdown]
# ## Wnioski
#
# Lista wszytskich właściwości: title, creator, date, issued, description, coverage, subject, type, format, identifier, publisher, relation, language, source, rights
#
# **Co na pewno przyda się: title, date, description, subject, identifier**
#
# Co może się przyda: creator, issued, type, publisher, language
#
# Co się NIE przyda: coverage, format, relation, source, rights

# %%
# sprawdzenie wartości dla niepewnych właściwości

fields = ["dc:creator", "dc:issued", "dc:type", "dc:publisher", "dc:language"]

dc = Namespace("http://purl.org/dc/elements/1.1/")

for field in fields:
    q = f"""
    SELECT DISTINCT ?value WHERE {{
        # ?s {field} ?value .
    }}
    LIMIT 20
    """
    print(10*"*"+field+10*"*")
    for row in g.query(q, initNs={"dc": dc}):
        print(row[0])
    print()
# Out:
# **********dc:creator**********
# Gęsiak, Leszek
# Labour Party
# Cambridge Anglo-Polish Society
#
# **********dc:issued**********
# 2004
# ca 1946
# 1948
# ca 1948
# ca 1900
# 1893
# ca 1882
# 1879
# 1860
# 1859
# 1872
# 1874
# 1884
# [1930-1936]
# [1878]
# 1944
# [1901]
# [1896]
# 1966
# 1966
#
# **********dc:type**********
# rozprawa doktorska
# druk ulotny
# afisz
# plakat
# klepsydra
#
# **********dc:publisher**********
# Uniwersytet Jagielloński w Krakowie
# I. Związkowa Drukarnia
# Jermułowicz i Bergman
# M. Stochalski
#
# **********dc:language**********
# pol
# eng
# ger
# yid
# fre
# rus

# %%
# NIE DZIAŁA DLA DUŻEJ LICZBY DANYCH - GRAF JEST NIECZYTELNY

from pyvis.network import Network

def visualise_graph(graph):
    net = Network(notebook=False, directed=True)
    net.toggle_physics(False)

    for s, p, o in graph:
        net.add_node(str(s), title=str(s))
        net.add_node(str(o), title=str(o))
        net.add_edge(str(s), str(o), title=str(p))

    net.write_html("graf_jbc.html")

#visualise_graph(g)
