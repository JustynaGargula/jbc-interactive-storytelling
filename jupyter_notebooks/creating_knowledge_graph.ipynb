# %% [markdown]
# # Tworzenie grafu wiedzy z pobranych wcześniej danych

# %%
from rdflib import Graph, Namespace
import re
from dataclasses import dataclass, field
from typing import List, Optional, Dict
from collections import defaultdict
from typing import Tuple
import json

# %%
DC = Namespace("http://purl.org/dc/elements/1.1/")

g = Graph()
g.parse("data/merged_graph_turtle.ttl", format="turtle")
print(f"Załadowano {len(g)} trójek")
# Out:
# Załadowano 3388 trójek

# %%
# funkcja normalizująca daty

def normalize(date_str):
    if not date_str:
        return None

    date_str = date_str.strip()

    # Wzorzec 1: zwykły rok (np. "1999")
    match = re.match(r"^(\d{4})$", date_str)
    if match:
        year = int(match.group(1))
        return {
            'original': date_str,
            'year': year,
            'century': (year - 1) // 100 + 1,
        }

    # Wzorzec 2: daty przybliżone (np. "ca 1999")
    match = re.match(r"^(ca|circa|c\.)\s*(\d{4})$", date_str, re.IGNORECASE)
    if match:
        year = int(match.group(2))
        return {
            'original': date_str,
            'year': year,
            'century': (year - 1) // 100 + 1,
            'is_approximate': True,
        }

    # Wzorzec 3: zakresy dat (np. "[1990-1999]")
    match = re.match(r"^\[?(\d{4})\s*-\s*(\d{4})\]?$", date_str)
    if match:
        start_year = int(match.group(1))
        end_year = int(match.group(2))
        return {
            'original': date_str,
            'year': start_year,
            'end_year': end_year,
            'century': (start_year - 1) // 100 + 1,
            'is_range': True,
        }

    # Wzorzec 4: wiek (np. "19 w.")
    match = re.match(r"^(\d{1,2})\s*w\.$", date_str)
    if match:
        century = int(match.group(1))
        year = (century - 1) * 100 + 50 # środek wieku
        return {
            'original': date_str,
            'year': year,
            'century': century,
            'is_approximate': True,
        }

    # Wzorzec 5: data w nawiasach kwadratowych (np. "[1990]")
    match = re.match(r"^\[?(\d{4})\s*\]?$", date_str)
    if match:
        year = int(match.group(1))
        return {
            'original': date_str,
            'year': year,
            'century': (year - 1) // 100 + 1,
        }

    return {
        'original': date_str,
        'year': None,
        'century': None,
        'is_unparsed': True,
    }

# %%
# test
test_dates = ["2004", "ca 1946", "[1930-1936]", "19 w.", "1893", "[1953]"]
for d in test_dates:
    print(f"{d} -> {normalize(d)}")
# Out:
# 2004 -> {'original': '2004', 'year': 2004, 'century': 21}
# ca 1946 -> {'original': 'ca 1946', 'year': 1946, 'century': 20, 'is_approximate': True}
# [1930-1936] -> {'original': '[1930-1936]', 'year': 1930, 'end_year': 1936, 'century': 20, 'is_range': True}
# 19 w. -> {'original': '19 w.', 'year': 1850, 'century': 19, 'is_approximate': True}
# 1893 -> {'original': '1893', 'year': 1893, 'century': 19}
# [1953] -> {'original': '[1953]', 'year': 1953, 'century': 20}

# %%
# klasa Document reprezentująca dokumenty w grafie
@dataclass
class Document:
    identifier: str
    title: str
    description: str = ""
    subjects: List[str] = field(default_factory=list)
    date_raw: str = ""
    date_normalized: Optional[Dict] = None
    year: Optional[int] = None
    century: Optional[int] = None
    creator: Optional[str] = None
    publisher: Optional[str] = None
    type: str = ""
    year_end: Optional[int] = None  # ← dla zakresów
    century: Optional[int] = None
    decade: Optional[int] = None
    is_approximate: bool = False     # o dacie
    is_range: bool = False           # o dacie
    is_unparsed: bool = False        # o dacie

    def __post_init__(self):
        if self.date_raw:
            self.date_normalized = normalize(self.date_raw)
            if self.date_normalized:
                self.year = self.date_normalized['year']
                self.century = self.date_normalized['century']
                self.year_end = self.date_normalized.get('year_end')
                self.is_approximate = self.date_normalized.get('is_approximate', False)
                self.is_range = self.date_normalized.get('is_range', False)
                self.is_unparsed = self.date_normalized.get('is_unparsed', False)

    def get_date_display(self) -> str:
        """Zwraca czytelny opis daty dla LLM"""
        if self.is_unparsed:
            return f"date uncertain: {self.date_raw}"
        if self.is_range and self.year_end:
            return f"{self.year}-{self.year_end}"
        if self.is_approximate:
            return f"circa {self.year}"
        if self.year:
            return str(self.year)
        return "date unknown"


@dataclass
class Subject:
    name: str
    documents: List[str] = field(default_factory=list)

    def add_document(self, doc_id: str):
        if doc_id not in self.documents:
            self.documents.append(doc_id)

# %%
class Relation:
    def __init__(self, source_id: str, target_id: str, relation_type: str, weight: float):
        self.source_id = source_id
        self.target_id = target_id
        self.relation_type = relation_type
        self.weight = weight

class KnowledgeGraph:
    def __init__(self):
        self.documents: Dict[str, Document] = {}
        self.subjects: Dict[str, Subject] = {}
        self.relations: List[Relation] = []

        self.by_year: Dict[int, List[str]] = defaultdict(list)
        self.by_century: Dict[int, List[str]] = defaultdict(list)
        self.by_subject: Dict[str, List[str]] = defaultdict(list)

    def add_document(self, doc: Document):
        self.documents[doc.identifier] = doc

        if doc.year is not None:
            self.by_year[doc.year].append(doc.identifier)
        if doc.century is not None:
            self.by_century[doc.century].append(doc.identifier)

        for subject_name in doc.subjects:
            subject_key = subject_name.lower()
            self.by_subject[subject_key].append(doc.identifier)

            if subject_key not in self.subjects:
                self.subjects[subject_key] = Subject(name=subject_name)
            self.subjects[subject_key].add_document(doc.identifier)

    def build_relations(self):

        # 1. wspólne subjects
        for subject_key, doc_ids in self.by_subject.items():
            if len(doc_ids) > 1:
                for i, doc_id1 in enumerate(doc_ids):
                    for doc_id2 in doc_ids[i+1:]:
                        if doc_id1 != doc_id2:
                            self.relations.append(Relation(doc_id1, doc_id2, "shared_subject", 1.0))


        # 2. chronologicznie
        sorted_years = sorted(self.by_year.keys())
        for i in range(len(sorted_years) - 1):
            year1 = sorted_years[i]
            year2 = sorted_years[i + 1]
            doc_ids1 = self.by_year[year1]
            doc_ids2 = self.by_year[year2]
            if year2 - year1 <= 5:      # odległość do 5 lat
                for doc_id1 in doc_ids1:
                    for doc_id2 in doc_ids2:
                        self.relations.append(Relation(doc_id1, doc_id2, "close_next", 1.0))


        # 3. te same century
        for century, doc_ids in self.by_century.items():
            if len(doc_ids) > 1:
                for i, doc_id1 in enumerate(doc_ids):
                    for doc_id2 in doc_ids[i+1:]:
                        if doc_id1 != doc_id2:
                            self.relations.append(Relation(doc_id1, doc_id2, "same_century", 0.5))

    def get_related_documents(self, doc_id: str, max_results: int = 5) -> List[Tuple[str, str, float]]:
        related = defaultdict(float)

        for relation in self.relations:
            if relation.source_id == doc_id:
                related[relation.target_id] += relation.weight
            elif relation.target_id == doc_id:
                related[relation.source_id] += relation.weight

        sorted_related = sorted(related.items(), key=lambda x: x[1], reverse=True)
        result = []
        for doc_id, score in sorted_related[:max_results]:
            result.append((self.documents[doc_id], score))

        return result

# %%
def build_kg_from_rdf(rdf_graph):
    kg = KnowledgeGraph()

    docs_data = defaultdict(lambda: {
        'title': None,
        'identifier': None,
        'description': None,
        'date': None,
        'subjects': [],
        'creator': None,
        'publisher': None,
        'type': None,
    })

    query = """
    PREFIX dc: <http://purl.org/dc/elements/1.1/>
    SELECT ?doc ?title ?date ?description ?subject ?identifier ?creator ?publisher ?type
    WHERE {
        # ?doc dc:title ?title .
        OPTIONAL { ?doc dc:date ?date }
        OPTIONAL { ?doc dc:description ?description }
        OPTIONAL { ?doc dc:subject ?subject }
        OPTIONAL { ?doc dc:identifier ?identifier }
        OPTIONAL { ?doc dc:creator ?creator }
        OPTIONAL { ?doc dc:publisher ?publisher }
        OPTIONAL { ?doc dc:type ?type }
    }
    """

    # zapisanie danych w odpowiednich zmiennych
    for row in rdf_graph.query(query):
        doc_uri = str(row.doc)

        if row.title:
            docs_data[doc_uri]['title'] = str(row.title)
        if row.date and not docs_data[doc_uri]['date']:
            docs_data[doc_uri]['date'] = str(row.date)
        if row.description:
            docs_data[doc_uri]['description'] = str(row.description)
        if row.subject:
            docs_data[doc_uri]['subjects'].append(str(row.subject))
        if row.identifier:
            docs_data[doc_uri]['identifier'] = str(row.identifier)
        if row.creator:
            docs_data[doc_uri]['creator'] = str(row.creator)
        if row.publisher:
            docs_data[doc_uri]['publisher'] = str(row.publisher)
        if row.type:
            docs_data[doc_uri]['type'] = str(row.type)

    # tworzenie obiektów Document i dodawanie ich do KnowledgeGraph
    for doc_uri, data in docs_data.items():
        if data['title'] and data['identifier']:
            doc = Document(
                identifier=data['identifier'],
                title=data['title'],
                description=data['description'] or "",
                subjects=data['subjects'],
                date_raw=data['date'] or  "",
                creator=data['creator'] or  "",
                publisher=data['publisher'] or  "",
                type=data['type'] or  "",
            )
            kg.add_document(doc)

    # budowanie relacji
    kg.build_relations()

    return kg

# %%
kg = build_kg_from_rdf(g)
print(f"Wczytano {len(kg.documents)} dokumentów do grafu wiedzy.")
print(f"Utworzono {len(kg.subjects)} tematów.")
print(f"Utworzono {len(kg.relations)} relacji między dokumentami.")
# Out:
# Wczytano 149 dokumentów do grafu wiedzy.
# Utworzono 192 tematów.
# Utworzono 967853 relacji między dokumentami.

# %%
# Testowe zapytania

# Statystyki
years_with_docs = [y for y in kg.by_year.keys()]
print(f"Zakres lat: {min(years_with_docs)} - {max(years_with_docs)}")

# Top 10 subjects
top_subjects = sorted(kg.subjects.items(),
                     key=lambda x: len(x[1].documents),
                     reverse=True)[:10]
print("\nTop 10 subjects:")
for subj_key, subj in top_subjects:
    print(f"  {subj.name}: {len(subj.documents)} dokumentów")

# Przykład: dokumenty z 20 wieku
docs_20c = kg.by_century.get(20, [])
print(f"\nDokumenty z XX wieku.: {len(docs_20c)}")

# Przykład: powiązane dokumenty
if kg.documents:
    first_doc_id = list(kg.documents.keys())[0]
    related = kg.get_related_documents(first_doc_id, max_results=3)
    print(f"\nDokumenty powiązane z '{kg.documents[first_doc_id].title}':")
    for doc, score in related:
        print(f"  - {doc.title} (score: {score:.2f})")
# Out:
# Zakres lat: 1859 - 2022
#
# Top 10 subjects:
#   duchowość: 126 dokumentów
#   nabożeństwo żałobne: 126 dokumentów
#   pogrzeb: 126 dokumentów
#   religia: 126 dokumentów
#   socjologia: 126 dokumentów
#   społeczeństwo: 126 dokumentów
#   druki ulotne 20 w.: 122 dokumentów
#   Kraków (Polska ; region): 108 dokumentów
#   druki ulotne 19 w.: 17 dokumentów
#   druki ulotne 21 w.: 10 dokumentów
#
# Dokumenty z XX wieku.: 120
#
# Dokumenty powiązane z '„Your Future”':
#   - Błażej Gastoł, doktór medycyny, profesor nadzwyczajny higieny, kierownik Katedry i Zakładu Higieny Akademii Medycznej w Krakowie [...] urodzony 15 lutego 1905 r. w Bieżanowie, zmarł w Krakowie dnia 6 grudnia 1966 r. [...] (score: 8.50)
#   - Ś. P. Zofia Gąsiorowska, emer. nauczycielka [...] przeżywszy lat 76 [...] zmarła dnia 8 sierpnia 1961 r. [...] (score: 8.50)
#   - Ś. P. Julian Gałek [...] zmarł dnia 3 stycznia 1960 roku [...] (score: 8.50)

# %%
def export_kg_to_jsonld(kg: KnowledgeGraph, output_file: str):
    context = {
    "@context": {
        "@vocab": "http://jbc.bj.uj.edu.pl/vocab/",
        "dc": "http://purl.org/dc/elements/1.1/",
        "title": "dc:title",
        "subject": "dc:subject",
        "date": "dc:date",
        "description": "dc:description",
        "identifier": "dc:identifier",
        "creator": "dc:creator",
        "publisher": "dc:publisher",
        "type": "dc:type",
        "hasRelation": "http://jbc.bj.uj.edu.pl/vocab/hasRelation",
        "relationType": "http://jbc.bj.uj.edu.pl/vocab/relationType",
        "relatedTo": "http://jbc.bj.uj.edu.pl/vocab/relatedTo",
        "weight": "http://jbc.bj.uj.edu.pl/vocab/weight",
        "year": "http://jbc.bj.uj.edu.pl/vocab/year",
        "century": "http://jbc.bj.uj.edu.pl/vocab/century",
        "year_end": "http://jbc.bj.uj.edu.pl/vocab/yearEnd",
        "isApproximate": "http://jbc.bj.uj.edu.pl/vocab/isApproximate",
        "isRange": "http://jbc.bj.uj.edu.pl/vocab/isRange",
        "dateDisplay": "http://jbc.bj.uj.edu.pl/vocab/dateDisplay",
    }
}

    documents = []
    for doc in kg.documents.values():
        doc_obj = {
            "@id": doc.identifier,
            "@type": "Document",
            "title": doc.title,
            "description": doc.description,
            "date": doc.date_raw,
            "dateDisplay": doc.get_date_display(),
            "year": doc.year,
            "century": doc.century,
            "subject": doc.subjects,
            "creator": doc.creator,
            "publisher": doc.publisher,
            "type": doc.type,
            "hasRelation": []
        }

        if doc.year_end:
            doc_obj["yearEnd"] = doc.year_end
        if doc.is_approximate:
            doc_obj["isApproximate"] = True
        if doc.is_range:
            doc_obj["isRange"] = True


        for rel in kg.relations:
            if rel.source_id == doc.identifier:
                doc_obj["hasRelation"].append({
                    "@type": "Relation",
                    "relationType": rel.relation_type,
                    "relatedTo": rel.target_id,
                    "weight": rel.weight,
                })
            elif rel.target_id == doc.identifier:
                doc_obj["hasRelation"].append({
                    "@type": "Relation",
                    "relationType": rel.relation_type,
                    "relatedTo": rel.source_id,
                    "weight": rel.weight,
                })
        documents.append(doc_obj)


    subjects = []
    for subj_key, subj in kg.subjects.items():
        subj_obj = {
            "@id": f"http://jbc.bj.uj.edu.pl/subject/{subj_key}",
            "@type": "Subject",
            "name": subj.name,
            "documents": subj.documents,
        }
        subjects.append(subj_obj)

    graph = {
        "@context": context["@context"],
        "@graph": documents + subjects
    }

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(graph, f, ensure_ascii=False, indent=2)

    print(f"Zapisano graf do {output_file}")
    print(f"  - Dokumentów: {len(documents)}")
    print(f"  - Subjects: {len(subjects)}")
    print(f"  - Relacji: {len(kg.relations)}")

    return graph

# %%
jsonld_graph = export_kg_to_jsonld(kg, "data/jbc_knowledge_graph.jsonld")
# Out:
# Zapisano graf do data/jbc_knowledge_graph.jsonld
#   - Dokumentów: 149
#   - Subjects: 192
#   - Relacji: 967853

# %%
print("\nPrzykładowy dokument w JSON-LD:")
print(json.dumps(jsonld_graph["@graph"][0], ensure_ascii=False, indent=2))
# Out:
# Przykładowy dokument w JSON-LD:
# {
#   "@id": "https://jbc.bj.uj.edu.pl/Content/499435/NDIGDZS024864.pdf",
#   "@type": "Document",
#   "title": "„Your Future”",
#   "description": "",
#   "date": "ca 1946",
#   "dateDisplay": "circa 1946",
#   "year": 1946,
#   "century": 20,
#   "subject": [
#     "Partia Pracy (Wielka Brytania)",
#     "Partia Pracy (Wielka Brytania)",
#     "druki ulotne 20 w.",
#     "druki ulotne 20 w.",
#     "laburzyści",
#     "laburzyści"
#   ],
#   "creator": "Labour Party",
#   "publisher": "",
#   "type": "druk ulotny",
#   "hasRelation": [
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/510136/NDIGDZS023940.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/510137/NDIGDZS023948.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/603763/NDIGDZS031138.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/630677/NDIGDZS021897.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/630680/NDIGDZS031805.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/630680/NDIGDZS031805.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981023/NDIGDZS106106.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981023/NDIGDZS106106.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981023/NDIGDZS106106.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981023/NDIGDZS106106.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981245/NDIGDZS106410_15874105.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981245/NDIGDZS106410_15874105.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981245/NDIGDZS106410_15874105.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981245/NDIGDZS106410_15874105.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981317/NDIGDZS106384.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981317/NDIGDZS106384.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981317/NDIGDZS106384.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981317/NDIGDZS106384.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981338/NDIGDZS106831.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981338/NDIGDZS106831.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981338/NDIGDZS106831.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981338/NDIGDZS106831.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981339/NDIGDZS106834.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981339/NDIGDZS106834.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981339/NDIGDZS106834.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981339/NDIGDZS106834.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981343/NDIGDZS106205.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981343/NDIGDZS106205.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981343/NDIGDZS106205.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981343/NDIGDZS106205.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981356/NDIGDZS106359.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981356/NDIGDZS106359.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981356/NDIGDZS106359.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981356/NDIGDZS106359.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981359/NDIGDZS106812.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981359/NDIGDZS106812.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981359/NDIGDZS106812.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981359/NDIGDZS106812.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981360/NDIGDZS106813.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981360/NDIGDZS106813.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981360/NDIGDZS106813.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981360/NDIGDZS106813.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981363/NDIGDZS106835.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981363/NDIGDZS106835.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981363/NDIGDZS106835.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981363/NDIGDZS106835.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981370/NDIGDZS106807.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981370/NDIGDZS106807.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981370/NDIGDZS106807.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981370/NDIGDZS106807.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981375/NDIGDZS106839.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981375/NDIGDZS106839.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981375/NDIGDZS106839.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981375/NDIGDZS106839.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981626/NDIGDZS106836.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981626/NDIGDZS106836.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981626/NDIGDZS106836.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981626/NDIGDZS106836.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981627/NDIGDZS106838.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981627/NDIGDZS106838.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981627/NDIGDZS106838.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/981627/NDIGDZS106838.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/982422/NDIGDZS106182.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/982422/NDIGDZS106182.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/982422/NDIGDZS106182.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/982422/NDIGDZS106182.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984656/NDIGDZS107687.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984656/NDIGDZS107687.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984656/NDIGDZS107687.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984656/NDIGDZS107687.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984675/NDIGDZS108361.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984675/NDIGDZS108361.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984675/NDIGDZS108361.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984675/NDIGDZS108361.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984677/NDIGDZS106446.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984677/NDIGDZS106446.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984677/NDIGDZS106446.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984677/NDIGDZS106446.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984679/NDIGDZS108366.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984679/NDIGDZS108366.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984679/NDIGDZS108366.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984679/NDIGDZS108366.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984680/NDIGDZS106447.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984680/NDIGDZS106447.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984680/NDIGDZS106447.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984680/NDIGDZS106447.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984681/NDIGDZS106456.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984681/NDIGDZS106456.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984681/NDIGDZS106456.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984681/NDIGDZS106456.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984682/NDIGDZS108373.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984682/NDIGDZS108373.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984682/NDIGDZS108373.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984682/NDIGDZS108373.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984683/NDIGDZS106466.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984683/NDIGDZS106466.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984683/NDIGDZS106466.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984683/NDIGDZS106466.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984684/NDIGDZS108474.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984684/NDIGDZS108474.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984684/NDIGDZS108474.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984684/NDIGDZS108474.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984685/NDIGDZS108473.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984685/NDIGDZS108473.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984685/NDIGDZS108473.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984685/NDIGDZS108473.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984686/NDIGDZS108471.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984686/NDIGDZS108471.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984686/NDIGDZS108471.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984686/NDIGDZS108471.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984687/NDIGDZS108464.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984687/NDIGDZS108464.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984687/NDIGDZS108464.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984687/NDIGDZS108464.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984688/NDIGDZS108426.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984688/NDIGDZS108426.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984688/NDIGDZS108426.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984688/NDIGDZS108426.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984689/NDIGDZS106468.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984689/NDIGDZS106468.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984689/NDIGDZS106468.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984689/NDIGDZS106468.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984690/NDIGDZS106469.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984690/NDIGDZS106469.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984690/NDIGDZS106469.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984690/NDIGDZS106469.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984691/NDIGDZS108420.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984691/NDIGDZS108420.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984691/NDIGDZS108420.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984691/NDIGDZS108420.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984692/NDIGDZS106488.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984692/NDIGDZS106488.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984692/NDIGDZS106488.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984692/NDIGDZS106488.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984693/NDIGDZS106491.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984693/NDIGDZS106491.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984693/NDIGDZS106491.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984693/NDIGDZS106491.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984694/NDIGDZS108382.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984694/NDIGDZS108382.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984694/NDIGDZS108382.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984694/NDIGDZS108382.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984695/NDIGDZS108374.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984695/NDIGDZS108374.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984695/NDIGDZS108374.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984695/NDIGDZS108374.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984697/NDIGDZS108380.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984697/NDIGDZS108380.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984697/NDIGDZS108380.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984697/NDIGDZS108380.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984699/NDIGDZS108375.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984699/NDIGDZS108375.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984699/NDIGDZS108375.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984699/NDIGDZS108375.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984702/NDIGDZS108377.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984702/NDIGDZS108377.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984702/NDIGDZS108377.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984702/NDIGDZS108377.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984703/NDIGDZS106492.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984703/NDIGDZS106492.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984703/NDIGDZS106492.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984703/NDIGDZS106492.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984704/NDIGDZS106497.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984704/NDIGDZS106497.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984704/NDIGDZS106497.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984704/NDIGDZS106497.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984725/NDIGDZS107688.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984725/NDIGDZS107688.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984725/NDIGDZS107688.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984725/NDIGDZS107688.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984727/NDIGDZS107877.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984727/NDIGDZS107877.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984727/NDIGDZS107877.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984727/NDIGDZS107877.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984731/NDIGDZS107886.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984731/NDIGDZS107886.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984731/NDIGDZS107886.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984731/NDIGDZS107886.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984734/NDIGDZS107889.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984734/NDIGDZS107889.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984734/NDIGDZS107889.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984734/NDIGDZS107889.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984735/NDIGDZS107890.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984735/NDIGDZS107890.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984735/NDIGDZS107890.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984735/NDIGDZS107890.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984737/NDIGDZS107891.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984737/NDIGDZS107891.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984737/NDIGDZS107891.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984737/NDIGDZS107891.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984738/NDIGDZS107892.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984738/NDIGDZS107892.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984738/NDIGDZS107892.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984738/NDIGDZS107892.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984739/NDIGDZS107895.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984739/NDIGDZS107895.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984739/NDIGDZS107895.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984739/NDIGDZS107895.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984741/NDIGDZS107905.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984741/NDIGDZS107905.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984741/NDIGDZS107905.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984741/NDIGDZS107905.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984742/NDIGDZS107908.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984742/NDIGDZS107908.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984742/NDIGDZS107908.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984742/NDIGDZS107908.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984744/NDIGDZS107920.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984744/NDIGDZS107920.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984744/NDIGDZS107920.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984744/NDIGDZS107920.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984765/NDIGDZS106556.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984765/NDIGDZS106556.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984765/NDIGDZS106556.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984765/NDIGDZS106556.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984767/NDIGDZS106557.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984767/NDIGDZS106557.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984767/NDIGDZS106557.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984767/NDIGDZS106557.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984768/NDIGDZS106563.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984768/NDIGDZS106563.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984768/NDIGDZS106563.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984768/NDIGDZS106563.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985321/NDIGDZS108317.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985321/NDIGDZS108317.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985321/NDIGDZS108317.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985321/NDIGDZS108317.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985322/NDIGDZS108319.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985322/NDIGDZS108319.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985322/NDIGDZS108319.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985322/NDIGDZS108319.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985323/NDIGDZS108320.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985323/NDIGDZS108320.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985323/NDIGDZS108320.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985323/NDIGDZS108320.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985324/NDIGDZS108321.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985324/NDIGDZS108321.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985324/NDIGDZS108321.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985324/NDIGDZS108321.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985325/NDIGDZS108323.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985325/NDIGDZS108323.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985325/NDIGDZS108323.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985325/NDIGDZS108323.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985326/NDIGDZS108339.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985326/NDIGDZS108339.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985326/NDIGDZS108339.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985326/NDIGDZS108339.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985327/NDIGDZS108345.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985327/NDIGDZS108345.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985327/NDIGDZS108345.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985327/NDIGDZS108345.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985345/NDIGDZS108771.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985345/NDIGDZS108771.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985345/NDIGDZS108771.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985345/NDIGDZS108771.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985346/NDIGDZS108772.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985346/NDIGDZS108772.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985346/NDIGDZS108772.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985346/NDIGDZS108772.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985347/NDIGDZS108787.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985347/NDIGDZS108787.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985347/NDIGDZS108787.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985347/NDIGDZS108787.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985348/NDIGDZS108789.pdf",
#       "weight": 1.0
#     },
#     {
#       "@type": "Relation",
#       "relationType": "shared_subject",
# ...
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984685/NDIGDZS108473.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984686/NDIGDZS108471.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984687/NDIGDZS108464.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984688/NDIGDZS108426.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984689/NDIGDZS106468.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984690/NDIGDZS106469.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984691/NDIGDZS108420.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984692/NDIGDZS106488.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984693/NDIGDZS106491.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984694/NDIGDZS108382.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984695/NDIGDZS108374.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984697/NDIGDZS108380.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984699/NDIGDZS108375.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984702/NDIGDZS108377.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984703/NDIGDZS106492.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984704/NDIGDZS106497.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984725/NDIGDZS107688.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984727/NDIGDZS107877.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984731/NDIGDZS107886.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984734/NDIGDZS107889.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984735/NDIGDZS107890.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984737/NDIGDZS107891.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984738/NDIGDZS107892.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984739/NDIGDZS107895.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984741/NDIGDZS107905.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984742/NDIGDZS107908.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984744/NDIGDZS107920.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984765/NDIGDZS106556.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984767/NDIGDZS106557.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/984768/NDIGDZS106563.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985321/NDIGDZS108317.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985322/NDIGDZS108319.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985323/NDIGDZS108320.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985324/NDIGDZS108321.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985325/NDIGDZS108323.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985326/NDIGDZS108339.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985327/NDIGDZS108345.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985345/NDIGDZS108771.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985346/NDIGDZS108772.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985347/NDIGDZS108787.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985348/NDIGDZS108789.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985349/NDIGDZS108793.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985350/NDIGDZS108795.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985351/NDIGDZS108798.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985352/NDIGDZS106832.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985353/NDIGDZS106830.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985355/NDIGDZS108427.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985356/NDIGDZS108249.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985357/NDIGDZS108472.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985360/NDIGDZS106824.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/985376/NDIGDZS108712.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986121/NDIGDZS108407.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986122/NDIGDZS108408.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986123/NDIGDZS108410.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986125/NDIGDZS108411.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986128/NDIGDZS108331.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986145/NDIGDZS108403.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986147/NDIGDZS108404.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986150/NDIGDZS108406.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986151/NDIGDZS108409.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986153/NDIGDZS108428.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986154/NDIGDZS108432.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986155/NDIGDZS108439.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986156/NDIGDZS108440.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986497/NDIGDZS108481.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986498/NDIGDZS108482.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986499/NDIGDZS108484.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986500/NDIGDZS108485.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986502/NDIGDZS108486.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986507/NDIGDZS109435.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986509/NDIGDZS109437.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986513/NDIGDZS108493.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986515/NDIGDZS108495.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986519/NDIGDZS108498.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986520/NDIGDZS108499.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986521/NDIGDZS108501.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986522/NDIGDZS108502.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986525/NDIGDZS108443.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986526/NDIGDZS108465.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986528/NDIGDZS108466.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/986866/NDIGDZS109678.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987041/NDIGDZS109497.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987066/NDIGDZS107960.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987067/NDIGDZS107961.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987068/NDIGDZS109663.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987069/NDIGDZS109664.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987070/NDIGDZS107962.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987071/NDIGDZS107965.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987738/NDIGDZS109962.pdf",
#       "weight": 0.5
#     },
#     {
#       "@type": "Relation",
#       "relationType": "same_century",
#       "relatedTo": "https://jbc.bj.uj.edu.pl/Content/987812/NDIGDZS109041.pdf",
#       "weight": 0.5
#     }
#   ],
#   "isApproximate": true
# }
